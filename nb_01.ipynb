# %%
# FB
## TODO: learn from https://github.com/DaWe35/Facebook-event-crawler/blob/master/Crawlr.py

# google

# %%
# !cd tutorial \
  && pwd \
  && scrapy crawl quotes
# Out:
# /home/jovyan/tutorial
# 2022-02-26 21:45:05 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: tutorial)
# 2022-02-26 21:45:05 [scrapy.utils.log] INFO: Versions: lxml 4.8.0.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 22.1.0, Python 3.10.2 | packaged by conda-forge | (main, Feb  1 2022, 19:28:35) [GCC 9.4.0], pyOpenSSL 21.0.0 (OpenSSL 1.1.1l  24 Aug 2021), cryptography 36.0.1, Platform Linux-5.4.0-1035-azure-x86_64-with-glibc2.27
# 2022-02-26 21:45:05 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2022-02-26 21:45:05 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'tutorial',
#  'NEWSPIDER_MODULE': 'tutorial.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['tutorial.spiders']}
# 2022-02-26 21:45:05 [scrapy.extensions.telnet] INFO: Telnet Password: 8c4b589e50ab74b2
# 2022-02-26 21:45:05 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
# ...

# %%
# 2) use the shell to inspect the data (open terminal & paste this)
# !cd tutorial \
  && scrapy shell 'http://quotes.toscrape.com/page/1/'
# Out:
# 2022-02-26 21:54:11 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: tutorial)
# 2022-02-26 21:54:11 [scrapy.utils.log] INFO: Versions: lxml 4.8.0.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 22.1.0, Python 3.10.2 | packaged by conda-forge | (main, Feb  1 2022, 19:28:35) [GCC 9.4.0], pyOpenSSL 21.0.0 (OpenSSL 1.1.1l  24 Aug 2021), cryptography 36.0.1, Platform Linux-5.4.0-1035-azure-x86_64-with-glibc2.27
# 2022-02-26 21:54:11 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2022-02-26 21:54:11 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'tutorial',
#  'DUPEFILTER_CLASS': 'scrapy.dupefilters.BaseDupeFilter',
#  'LOGSTATS_INTERVAL': 0,
#  'NEWSPIDER_MODULE': 'tutorial.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['tutorial.spiders']}
# 2022-02-26 21:54:11 [scrapy.extensions.telnet] INFO: Telnet Password: 2a5cc38f2a8d5429
# 2022-02-26 21:54:11 [scrapy.middleware] INFO: Enabled extensions:
# ...
